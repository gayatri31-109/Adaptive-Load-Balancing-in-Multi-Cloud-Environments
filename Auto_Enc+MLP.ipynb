# %% [markdown]
# # Import and data loading

# %%
# =========================
# 1. IMPORT LIBRARIES
# =========================
import pandas as pd
import numpy as np
import ast

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# =========================
# 2. LOAD DATA
# =========================

path = r"C:\Users\hp\Desktop\Major Pr\borg_traces_data.csv"

df = pd.read_csv(path)

print("Shape:", df.shape)
print(df.head())
# Out:
# Shape: (405894, 34)
#    Unnamed: 0           time  instance_events_type  collection_id  \
# 0           0              0                     2    94591244395
# 1           1  2517305308183                     2   260697606809
# 2           2   195684022913                     6   276227177776
# 3           3              0                     2    10507389885
# 4           4  1810627494172                     3    25911621841
#
#    scheduling_class  collection_type  priority  alloc_collection_id  \
# 0                 3                1       200                    0
# 1                 2                0       360         221495397286
# 2                 2                0       103                    0
# 3                 3                0       200                    0
# 4                 2                0         0                    0
#
#    instance_index    machine_id  ... assigned_memory page_cache_memory  \
# 0             144  168846390496  ...        0.014435          0.000415
# 1             335      85515092  ...        0.000000          0.000000
# 2             376  169321752432  ...        0.010422          0.000235
# 3            1977  178294817221  ...        0.041626          0.000225
# 4            3907  231364893292  ...        0.000272          0.000010
#
#    cycles_per_instruction memory_accesses_per_instruction sample_rate  \
# 0                     NaN                             NaN         1.0
# 1                     NaN                             NaN         1.0
# 2                0.939919                        0.001318         1.0
# 3                1.359102                        0.007643         1.0
# 4                     NaN                             NaN         1.0
#
#                               cpu_usage_distribution  \
# 0  [0.00314331 0.00381088 0.00401306 0.00415039 0...
# 1  [1.23977661e-05 1.23977661e-05 1.23977661e-05 ...
# 2  [0.01344299 0.01809692 0.0201416  0.02246094 0...
# 3  [0.03704834 0.04125977 0.04290771 0.04425049 0...
# 4  [0.         0.         0.         0.         0...
#
#                          tail_cpu_usage_distribution  cluster     event  \
# 0  [0.00535583 0.00541687 0.00548553 0.00554657 0...        7      FAIL
# 1  [1.23977661e-05 1.23977661e-05 1.23977661e-05 ...        7      FAIL
# 2  [0.02902222 0.02929688 0.0295105  0.0296936  0...        7  SCHEDULE
# 3  [0.05535889 0.05584717 0.05633545 0.05718994 0...        8      FAIL
# 4  [0.00041485 0.00041485 0.00041485 0.00041485 0...        2    FINISH
#
#    failed
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
#
# [5 rows x 34 columns]

# %%
# =========================
# 3. DATA UNDERSTANDING
# =========================

print("\nColumns:\n", df.columns)

print("\nInfo:")
print(df.info())

print("\nMissing values:")
print(df.isna().sum())

print("\nStatistics:")
print(df.describe())
# Out:
# Columns:
#  Index(['Unnamed: 0', 'time', 'instance_events_type', 'collection_id',
#        'scheduling_class', 'collection_type', 'priority',
#        'alloc_collection_id', 'instance_index', 'machine_id',
#        'resource_request', 'constraint', 'collections_events_type', 'user',
#        'collection_name', 'collection_logical_name',
#        'start_after_collection_ids', 'vertical_scaling', 'scheduler',
#        'start_time', 'end_time', 'average_usage', 'maximum_usage',
#        'random_sample_usage', 'assigned_memory', 'page_cache_memory',
#        'cycles_per_instruction', 'memory_accesses_per_instruction',
#        'sample_rate', 'cpu_usage_distribution', 'tail_cpu_usage_distribution',
#        'cluster', 'event', 'failed'],
#       dtype='object')
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405894 entries, 0 to 405893
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Unnamed: 0                       405894 non-null  int64
#  1   time                             405894 non-null  int64
#  2   instance_events_type             405894 non-null  int64
#  3   collection_id                    405894 non-null  int64
#  4   scheduling_class                 405894 non-null  int64
#  5   collection_type                  405894 non-null  int64
#  6   priority                         405894 non-null  int64
#  7   alloc_collection_id              405894 non-null  int64
#  8   instance_index                   405894 non-null  int64
#  9   machine_id                       405894 non-null  int64
#  10  resource_request                 405120 non-null  object
#  11  constraint                       405894 non-null  object
#  12  collections_events_type          405894 non-null  int64
#  13  user                             405894 non-null  object
#  14  collection_name                  405894 non-null  object
#  15  collection_logical_name          405894 non-null  object
#  16  start_after_collection_ids       405894 non-null  object
#  17  vertical_scaling                 404935 non-null  float64
#  18  scheduler                        404935 non-null  float64
#  19  start_time                       405894 non-null  int64
#  20  end_time                         405894 non-null  int64
#  21  average_usage                    405894 non-null  object
#  22  maximum_usage                    405894 non-null  object
#  23  random_sample_usage              405894 non-null  object
#  24  assigned_memory                  405894 non-null  float64
#  25  page_cache_memory                405894 non-null  float64
#  26  cycles_per_instruction           281206 non-null  float64
#  27  memory_accesses_per_instruction  281206 non-null  float64
#  28  sample_rate                      405894 non-null  float64
#  29  cpu_usage_distribution           405894 non-null  object
#  30  tail_cpu_usage_distribution      405894 non-null  object
#  31  cluster                          405894 non-null  int64
#  32  event                            405894 non-null  object
#  33  failed                           405894 non-null  int64
# dtypes: float64(7), int64(15), object(12)
# memory usage: 105.3+ MB
# None
#
# Missing values:
# Unnamed: 0                              0
# time                                    0
# instance_events_type                    0
# collection_id                           0
# scheduling_class                        0
# collection_type                         0
# priority                                0
# alloc_collection_id                     0
# instance_index                          0
# machine_id                              0
# resource_request                      774
# constraint                              0
# collections_events_type                 0
# user                                    0
# collection_name                         0
# collection_logical_name                 0
# start_after_collection_ids              0
# vertical_scaling                      959
# scheduler                             959
# start_time                              0
# end_time                                0
# average_usage                           0
# maximum_usage                           0
# random_sample_usage                     0
# assigned_memory                         0
# page_cache_memory                       0
# cycles_per_instruction             124688
# memory_accesses_per_instruction    124688
# sample_rate                             0
# cpu_usage_distribution                  0
# tail_cpu_usage_distribution             0
# cluster                                 0
# event                                   0
# failed                                  0
# dtype: int64
#
# Statistics:
#           Unnamed: 0          time  instance_events_type  collection_id  \
# count  405894.000000  4.058940e+05         405894.000000   4.058940e+05
# mean   202946.500000  6.927465e+13              2.945983   3.590897e+11
# std    117171.649419  2.507511e+16              2.045794   2.446122e+11
# min         0.000000  0.000000e+00              0.000000   6.824000e+03
# 25%    101473.250000  2.674747e+11              2.000000   2.125496e+11
# 50%    202946.500000  1.084800e+12              3.000000   3.108868e+11
# 75%    304419.750000  1.766117e+12              5.000000   4.918812e+11
# max    405893.000000  9.223372e+18             10.000000   8.258532e+11
#
#        scheduling_class  collection_type       priority  alloc_collection_id  \
# count     405894.000000    405894.000000  405894.000000         4.058940e+05
# mean           1.266870         0.087782     147.913793         7.021801e+10
# std            1.014087         0.282977     116.656633         1.673475e+11
# min            0.000000         0.000000       0.000000         0.000000e+00
# 25%            0.000000         0.000000     103.000000         0.000000e+00
# 50%            1.000000         0.000000     105.000000         0.000000e+00
# 75%            2.000000         0.000000     200.000000         0.000000e+00
# max            3.000000         1.000000     450.000000         7.426667e+11
#
#        instance_index    machine_id  ...      scheduler    start_time  \
# count   405894.000000  4.058940e+05  ...  404935.000000  4.058940e+05
# mean      5034.756259  8.491885e+10  ...       0.370422  1.238422e+12
# std      11848.537486  1.377903e+11  ...       0.482918  7.965088e+11
# min          0.000000 -1.000000e+00  ...       0.000000  3.000000e+08
# 25%        401.000000  2.932044e+09  ...       0.000000  5.219700e+11
# 50%       1380.000000  2.008985e+10  ...       0.000000  1.274400e+12
# 75%       4200.000000  1.318590e+11  ...       1.000000  1.944000e+12
# max     177107.000000  8.254274e+11  ...       1.000000  2.678400e+12
#
#            end_time  assigned_memory  page_cache_memory  \
# count  4.058940e+05    405894.000000      405894.000000
# mean   1.238634e+12         0.008927           0.000398
# std    7.965134e+11         0.024937           0.000550
# min    6.000000e+08         0.000000           0.000000
# 25%    5.219710e+11         0.000196           0.000008
# 50%    1.274509e+12         0.002693           0.000227
# 75%    1.944300e+12         0.006683           0.000539
# max    2.678700e+12         0.286133           0.008453
#
#        cycles_per_instruction  memory_accesses_per_instruction    sample_rate  \
# count           281206.000000                    281206.000000  405894.000000
# mean                 2.185379                         0.010722       0.999223
# std                  1.256117                         0.007753       0.010239
# min                  0.252846                         0.000125       0.110000
# 25%                  1.067229                         0.004329       1.000000
# 50%                  1.918681                         0.009506       1.000000
# 75%                  3.156894                         0.016435       1.000000
# max                105.275932                         0.084292       1.000000
#
#              cluster         failed
# count  405894.000000  405894.000000
# mean        4.563613       0.228331
# std         2.208008       0.419757
# min         1.000000       0.000000
# 25%         3.000000       0.000000
# 50%         5.000000       0.000000
# 75%         6.000000       0.000000
# max         8.000000       1.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# # Drop useless columns

# %%
# =========================
# 4. DROP USELESS COLUMNS
# =========================

drop_cols = [
    'Unnamed: 0',
    'constraint',
    'user',
    'collection_name',
    'collection_logical_name',
    'start_after_collection_ids',
    'cpu_usage_distribution',
    'tail_cpu_usage_distribution'
]

df.drop(columns=drop_cols, inplace=True, errors='ignore')

# %% [markdown]
# # Parse dictionary columns

# %%
#Parse dictionary columns
{'cpus': 0.02, 'memory': 0.01}
# Out:
# {'cpus': 0.02, 'memory': 0.01}

# %%
def extract_value(x, key):
    try:
        return ast.literal_eval(x)[key]
    except:
        return np.nan

# %%
#Apply Parsing
df['req_cpu'] = df['resource_request'].apply(lambda x: extract_value(x, 'cpus'))
df['req_mem'] = df['resource_request'].apply(lambda x: extract_value(x, 'memory'))

df['avg_cpu'] = df['average_usage'].apply(lambda x: extract_value(x, 'cpus'))
df['avg_mem'] = df['average_usage'].apply(lambda x: extract_value(x, 'memory'))

df['max_cpu'] = df['maximum_usage'].apply(lambda x: extract_value(x, 'cpus'))
df['max_mem'] = df['maximum_usage'].apply(lambda x: extract_value(x, 'memory'))

# %%
df.drop(columns=[
    'resource_request',
    'average_usage',
    'maximum_usage',
    'random_sample_usage'
], inplace=True)

# %% [markdown]
# # Feature Engineering

# %%
# runtime
df['runtime'] = df['end_time'] - df['start_time']

# scheduling delay
df['delay'] = df['start_time'] - df['time']

# CPU efficiency
df['cpu_efficiency'] = df['avg_cpu'] / (df['req_cpu'] + 1e-6)

# %% [markdown]
# # Handle Missing Values

# %%
df.fillna({
    'vertical_scaling': 0,
    'scheduler': 0,
    'cycles_per_instruction': df['cycles_per_instruction'].median(),
    'memory_accesses_per_instruction': df['memory_accesses_per_instruction'].median()
}, inplace=True)

df.fillna(0, inplace=True)


"""stats:

vertical_scaling → 959 missing

scheduler → 959 missing

cycles_per_instruction → many missing

memory_accesses_per_instruction → many missing"""
# Out:
# 'stats:\n\nvertical_scaling → 959 missing\n\nscheduler → 959 missing\n\ncycles_per_instruction → many missing\n\nmemory_accesses_per_instruction → many missing'

# %% [markdown]
# # Encode categorical column

# %%
df['event'] = df['event'].astype('category').cat.codes

# %% [markdown]
# # Keep only numeric columns

# %%
df = df.select_dtypes(include=[np.number])

print("After cleaning shape:", df.shape)
# Out:
# After cleaning shape: (405894, 31)

# %% [markdown]
# # Feature Selection

# %%
features = [
    'priority',
    'machine_id',
    'req_cpu','req_mem',
    'avg_cpu','avg_mem',
    'max_cpu','max_mem',
    'assigned_memory',
    'page_cache_memory',
    'cycles_per_instruction',
    'memory_accesses_per_instruction',
    'runtime',
    'delay',
    'event',
    'failed'
]

df = df[features]

# %% [markdown]
# # Choose Target predict CPU usage

# %%
X = df.drop(columns=['avg_cpu'])
y = df['avg_cpu']

# %% [markdown]
# # Scaling

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

print("Train:", X_train.shape)
print("Test:", X_test.shape)
# Out:
# Train: (324715, 15)
# Test: (81179, 15)

# %% [markdown]
# # Save clean dataset

# %%
clean_df = pd.concat([pd.DataFrame(X_scaled), y.reset_index(drop=True)], axis=1)

clean_df.to_csv("clean_borg_data.csv", index=False)
print("Clean data saved!")
# Out:
# Clean data saved!

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# target
y = df['avg_cpu']   # or your target column

# numeric features only
X = df.select_dtypes(include=[np.number]).drop(columns=['avg_cpu'])

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

y_train = np.array(y_train)
y_test  = np.array(y_test)

# %% [markdown]
# # Autoencoder + MLP (Feature compression)

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, Sequential
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

#AutoEncoder
inp = Input(shape=(X_train.shape[1],))

encoded = Dense(64, activation='relu')(inp)
encoded = Dense(32, activation='relu')(encoded)

decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(X_train.shape[1])(decoded)

autoencoder = Model(inp, decoded)
encoder = Model(inp, encoded)

autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.fit(
    X_train, X_train,
    epochs=10,
    batch_size=512,
    validation_split=0.2
)

#Compress Features
X_train_enc = encoder.predict(X_train)
X_test_enc  = encoder.predict(X_test)

print(X_train_enc.shape)

#MLP on encoded features
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train_enc.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = model.fit(
    X_train_enc, y_train,
    epochs=20,
    batch_size=512,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0210 - val_loss: 1.4122e-04
# Epoch 2/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0081e-04 - val_loss: 3.2888e-05
# Epoch 3/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6423e-05 - val_loss: 1.6225e-05
# Epoch 4/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4463e-05 - val_loss: 1.1372e-05
# Epoch 5/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.0857e-05 - val_loss: 7.6799e-06
# Epoch 6/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.2840e-06 - val_loss: 4.4257e-06
# Epoch 7/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.9360e-06 - val_loss: 6.9555e-06
# Epoch 8/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6702e-06 - val_loss: 2.1631e-06
# Epoch 9/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6498e-06 - val_loss: 9.3492e-07
# Epoch 10/10
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6892e-06 - val_loss: 7.2545e-07
# 10148/10148 ━━━━━━━━━━━━━━━━━━━━ 6s 605us/step
# 2537/2537 ━━━━━━━━━━━━━━━━━━━━ 2s 605us/step
# (324715, 32)
# Epoch 1/20
# C:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0057 - mae: 0.0362 - val_loss: 5.8312e-05 - val_mae: 0.0049
# Epoch 2/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 5.4271e-05 - mae: 0.0046 - val_loss: 4.0192e-05 - val_mae: 0.0039
# Epoch 3/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 4.1749e-05 - mae: 0.0038 - val_loss: 3.7977e-05 - val_mae: 0.0039
# Epoch 4/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.5503e-05 - mae: 0.0035 - val_loss: 4.0189e-05 - val_mae: 0.0043
# Epoch 5/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2930e-05 - mae: 0.0034 - val_loss: 2.9880e-05 - val_mae: 0.0033
# Epoch 6/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.1070e-05 - mae: 0.0033 - val_loss: 2.8272e-05 - val_mae: 0.0030
# Epoch 7/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.9356e-05 - mae: 0.0032 - val_loss: 2.7375e-05 - val_mae: 0.0031
# Epoch 8/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.9887e-05 - mae: 0.0034 - val_loss: 3.7035e-05 - val_mae: 0.0044
# Epoch 9/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.0079e-05 - mae: 0.0035 - val_loss: 3.0232e-05 - val_mae: 0.0037
# Epoch 10/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7712e-05 - mae: 0.0032 - val_loss: 3.1053e-05 - val_mae: 0.0038
# Epoch 11/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 3.0968e-05 - mae: 0.0036 - val_loss: 2.4360e-05 - val_mae: 0.0028
# Epoch 12/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7506e-05 - mae: 0.0033 - val_loss: 3.6084e-05 - val_mae: 0.0044
# Epoch 13/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.6754e-05 - mae: 0.0032 - val_loss: 2.4699e-05 - val_mae: 0.0031
# Epoch 14/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7339e-05 - mae: 0.0033 - val_loss: 2.4552e-05 - val_mae: 0.0029
# Epoch 15/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.7426e-05 - mae: 0.0033 - val_loss: 4.4184e-05 - val_mae: 0.0052
# Epoch 16/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.6596e-05 - mae: 0.0033 - val_loss: 2.1842e-05 - val_mae: 0.0027
# Epoch 17/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.5166e-05 - mae: 0.0031 - val_loss: 2.3792e-05 - val_mae: 0.0031
# Epoch 18/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.4793e-05 - mae: 0.0031 - val_loss: 2.2972e-05 - val_mae: 0.0030
# Epoch 19/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4128e-05 - mae: 0.0031 - val_loss: 2.0039e-05 - val_mae: 0.0026
# Epoch 20/20
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 2.3059e-05 - mae: 0.0030 - val_loss: 2.9298e-05 - val_mae: 0.0037

# %%
y_pred = model.predict(X_test_enc).flatten()

print("\n===== Autoencoder + MLP RESULTS =====")
print("MAE :", mean_absolute_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2  :", r2_score(y_test, y_pred))
# Out:
# 2537/2537 ━━━━━━━━━━━━━━━━━━━━ 2s 625us/step
#
# ===== Autoencoder + MLP RESULTS =====
# MAE : 0.003733807412605434
# RMSE: 0.005447975150849958
# R2  : 0.9145258738466723

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train','val'])
plt.title("Loss Curve")
plt.show()

# %%
plt.plot(y_test[:1000], label='Actual')
plt.plot(y_pred[:1000], label='Predicted')
plt.legend()
plt.show()

# %%
plt.scatter(y_test, y_pred, alpha=0.3)
plt.plot([0,1],[0,1],'r')
plt.show()

# %%
plt.plot(y_test - y_pred)
plt.title("Residuals")
plt.show()
